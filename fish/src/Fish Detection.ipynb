# %%
# %matplotlib inline
import keras
import numpy as np
import scipy.misc
import matplotlib.pyplot as plt
import keras.applications
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions

# %%
img = scipy.misc.imread('../train/ALB/img_00003.jpg')

# %%
img = scipy.misc.imread('../train/ALB/img_00003.jpg')
x = np.expand_dims(img, axis=0)
x = np.transpose(x, (0, 3, 2, 1)).copy()
x = x.astype(np.float64)
#x = preprocess_input(x)

# %%
img = img.astype(np.float32)

# %%
plt.imshow(img)
plt.colorbar()

# %%
plt.imshow(np.transpose(x[0], (2,1,0)))
plt.colorbar()

# %%
img_2 = img[50:200, 250:750]

# %%
plt.imshow(img_2)

# %%
x = scipy.misc.imresize(img_2, (224, 224))

# %%
plt.imshow(x)

# %%
x = np.swapaxes(x, 0, 2)

# %%
x = np.array([x], dtype=np.float32)
x = preprocess_input(x)

# %%
x[0].shape
# Out:
# (3, 224, 224)

# %%
plt.imshow(np.swapaxes(x[0], 0, 2))

# %%
model = keras.applications.vgg16.VGG16(include_top=True, weights='imagenet')
# Out:
# ...
# 553435136/553466928 [============================>.] - ETA: 0s

# %%
# %time predictions = model.predict(x)
# Out:
# Wall time: 103 ms

# %%
decode_predictions(predictions, top=10)
# Out:
# [[('n04552348', 'warplane', 0.077905849),
#   ('n01855032', 'red-breasted_merganser', 0.07363984),
#   ('n09229709', 'bubble', 0.034118339),
#   ('n04273569', 'speedboat', 0.071812987),
#   ('n02860847', 'bobsled', 0.04195109),
#   ('n02687172', 'aircraft_carrier', 0.025307452),
#   ('n04037443', 'racer', 0.02342617),
#   ('n01484850', 'great_white_shark', 0.021523874),
#   ('n04252077', 'snowmobile', 0.019769112),
#   ('n01443537', 'goldfish', 0.018335281)]]
